# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()

dept = [("Finance",10), \
    ("Marketing",20), \
    ("Sales",30), \
    ("IT",40) \
  ]
deptColumns = ["dept_name","dept_id"]
deptDF = spark.createDataFrame(data=dept, schema = deptColumns)
deptDF.show(truncate=False)
# Out:
# +---------+-------+
# |dept_name|dept_id|
# +---------+-------+
# |Finance  |10     |
# |Marketing|20     |
# |Sales    |30     |
# |IT       |40     |
# +---------+-------+

# %%
dataCollect = deptDF.collect()
print(dataCollect)
# Out:
# [Row(dept_name='Finance', dept_id=10), Row(dept_name='Marketing', dept_id=20), Row(dept_name='Sales', dept_id=30), Row(dept_name='IT', dept_id=40)]

# %%
for row in dataCollect:
    print(row['dept_name'] + "," +str(row['dept_id']))
# Out:
# Finance,10
# Marketing,20
# Sales,30
# IT,40

# %%
#Returns value of First Row, First Column which is "Finance"
deptDF.collect()[0][0]
# Out:
# Out[4]: 'Finance'

# %%
"""
deptDF.collect() returns Array of Row type.
deptDF.collect()[0] returns the first element in an array (1st row).
deptDF.collect[0][0] returns the value of the first row & first column.
"""

deptDF.show(truncate= False)

dataCollect = deptDF.select("dept_name").collect()
print(dataCollect)

dataCollect = deptDF.select("dept_name").collect()[1]
print(dataCollect)

dataCollect = deptDF.select("dept_name").collect[0][0]
print(dataCollect)
# Out:
# +---------+-------+
# |dept_name|dept_id|
# +---------+-------+
# |Finance  |10     |
# |Marketing|20     |
# |Sales    |30     |
# |IT       |40     |
# +---------+-------+
#
# [Row(dept_name='Finance'), Row(dept_name='Marketing'), Row(dept_name='Sales'), Row(dept_name='IT')]
# Row(dept_name='Marketing')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-1260570378506729> in <module>
#      13 print(dataCollect)
#      14
# ---> 15 dataCollect = deptDF.select("dept_name").collect[0][0]
#      16 print(dataCollect)
#
# TypeError: 'method' object is not subscriptable
