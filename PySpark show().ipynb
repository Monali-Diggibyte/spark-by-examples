# %%
def show(self, n=20, truncate=True, vertical=False)
# Out:
#   File "<command-1951371118152230>", line 1
#     def show(self, n=20, truncate=True, vertical=False)
#                                                        ^
# SyntaxError: invalid syntax

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()
columns = ["Seqno","Quote"]
data = [("1", "Be the change that you wish to see in the world"),
    ("2", "Everyone thinks of changing the world, but no one thinks of changing himself."),
    ("3", "The purpose of our lives is to be happy."),
    ("4", "Be cool."),
       ("5", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("6", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("7", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("8", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("9", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("10", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("11", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("12", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("13", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("14", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("15", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("16", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("17", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("18", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("19", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("20", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("21", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("22", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("23", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("24", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("25", "Everyone thinks of changing the world, but no one thinks of changing himself."),
        ("26", "Everyone thinks of changing the world, but no one thinks of changing himself."),
       ]
df = spark.createDataFrame(data,columns)
df.show()
# Out:
# +-----+--------------------+
# |Seqno|               Quote|
# +-----+--------------------+
# |    1|Be the change tha...|
# |    2|Everyone thinks o...|
# |    3|The purpose of ou...|
# |    4|            Be cool.|
# |    5|Everyone thinks o...|
# |    6|Everyone thinks o...|
# |    7|Everyone thinks o...|
# |    8|Everyone thinks o...|
# |    9|Everyone thinks o...|
# |   10|Everyone thinks o...|
# |   11|Everyone thinks o...|
# |   12|Everyone thinks o...|
# |   13|Everyone thinks o...|
# |   14|Everyone thinks o...|
# |   15|Everyone thinks o...|
# |   16|Everyone thinks o...|
# |   17|Everyone thinks o...|
# |   18|Everyone thinks o...|
# |   19|Everyone thinks o...|
# |   20|Everyone thinks o...|
# +-----+--------------------+
# only showing top 20 rows

# %%
df.show(50,truncate=False)
# Out:
# +-----+-----------------------------------------------------------------------------+
# |Seqno|Quote                                                                        |
# +-----+-----------------------------------------------------------------------------+
# |1    |Be the change that you wish to see in the world                              |
# |2    |Everyone thinks of changing the world, but no one thinks of changing himself.|
# |3    |The purpose of our lives is to be happy.                                     |
# |4    |Be cool.                                                                     |
# |5    |Everyone thinks of changing the world, but no one thinks of changing himself.|
# |6    |Everyone thinks of changing the world, but no one thinks of changing himself.|
# |7    |Everyone thinks of changing the world, but no one thinks of changing himself.|
# |8    |Everyone thinks of changing the world, but no one thinks of changing himself.|
# ...

# %%
df.show(5,truncate=False)
# Out:
# +-----+-----------------------------------------------------------------------------+
# |Seqno|Quote                                                                        |
# +-----+-----------------------------------------------------------------------------+
# |1    |Be the change that you wish to see in the world                              |
# |2    |Everyone thinks of changing the world, but no one thinks of changing himself.|
# |3    |The purpose of our lives is to be happy.                                     |
# |4    |Be cool.                                                                     |
# |5    |Everyone thinks of changing the world, but no one thinks of changing himself.|
# +-----+-----------------------------------------------------------------------------+
# only showing top 5 rows

# %%
# Display 5 rows & column values 25 characters
df.show(5,truncate=25)
# Out:
# +-----+-------------------------+
# |Seqno|                    Quote|
# +-----+-------------------------+
# |    1|Be the change that you...|
# |    2|Everyone thinks of cha...|
# |    3|The purpose of our liv...|
# |    4|                 Be cool.|
# |    5|Everyone thinks of cha...|
# +-----+-------------------------+
# only showing top 5 rows

# %%
# Display DataFrame rows & columns vertically
df.show(n=5,truncate=25,vertical=True)
# Out:
# -RECORD 0--------------------------
#  Seqno | 1
#  Quote | Be the change that you...
# -RECORD 1--------------------------
#  Seqno | 2
#  Quote | Everyone thinks of cha...
# -RECORD 2--------------------------
#  Seqno | 3
#  Quote | The purpose of our liv...
# -RECORD 3--------------------------
#  Seqno | 4
#  Quote | Be cool.
# -RECORD 4--------------------------
#  Seqno | 5
#  Quote | Everyone thinks of cha...
# only showing top 5 rows

# %%
 # Display DataFrame rows & columns vertically
df.show(n=5,truncate= False,vertical=True)
# Out:
# -RECORD 0------------------------------------------------------------------------------
#  Seqno | 1
#  Quote | Be the change that you wish to see in the world
# -RECORD 1------------------------------------------------------------------------------
#  Seqno | 2
#  Quote | Everyone thinks of changing the world, but no one thinks of changing himself.
# -RECORD 2------------------------------------------------------------------------------
#  Seqno | 3
#  Quote | The purpose of our lives is to be happy.
# -RECORD 3------------------------------------------------------------------------------
#  Seqno | 4
#  Quote | Be cool.
# -RECORD 4------------------------------------------------------------------------------
#  Seqno | 5
#  Quote | Everyone thinks of changing the world, but no one thinks of changing himself.
# only showing top 5 rows
