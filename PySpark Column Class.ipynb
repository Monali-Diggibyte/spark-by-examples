# %%
from pyspark.sql.functions import lit
colObj = lit("sparkbyexamples.com")

# %%
data=[("James",23),("Ann",40)]
df=spark.createDataFrame(data).toDF("name.fname","gender")
df.printSchema()

# Using DataFrame object (df)
df.select(df.gender).show()
df.select(df["gender"]).show()
#Accessing column name with dot (with backticks)
df.select(df["`name.fname`"]).show()

#Using SQL col() function
from pyspark.sql.functions import col
df.select(col("gender")).show()
#Accessing column name with dot (with backticks)
df.select(col("`name.fname`")).show()
# Out:
# root
#  |-- name.fname: string (nullable = true)
#  |-- gender: long (nullable = true)
#
# +------+
# |gender|
# +------+
# |    23|
# |    40|
# +------+
#
# +------+
# |gender|
# +------+
# |    23|
# |    40|
# +------+
#
# +----------+
# |name.fname|
# +----------+
# |     James|
# |       Ann|
# +----------+
#
# +------+
# |gender|
# +------+
# |    23|
# |    40|
# +------+
#
# +----------+
# |name.fname|
# +----------+
# |     James|
# |       Ann|
# +----------+

# %%
#Create DataFrame with struct using Row class
from pyspark.sql import Row
data=[Row(name="James",prop=Row(hair="black",eye="blue")),
      Row(name="Ann",prop=Row(hair="grey",eye="black"))]
df=spark.createDataFrame(data)
df.printSchema()
#root
# |-- name: string (nullable = true)
# |-- prop: struct (nullable = true)
# |    |-- hair: string (nullable = true)
# |    |-- eye: string (nullable = true)

#Access struct column
df.select(df.prop.hair).show()
df.select(df["prop.hair"]).show()
df.select(col("prop.hair")).show()

#Access all columns from struct
df.select(col("prop.*")).show()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- prop: struct (nullable = true)
#  |    |-- hair: string (nullable = true)
#  |    |-- eye: string (nullable = true)
#
# +---------+
# |prop.hair|
# +---------+
# |    black|
# |     grey|
# +---------+
#
# +-----+
# | hair|
# +-----+
# |black|
# | grey|
# +-----+
#
# +-----+
# | hair|
# +-----+
# |black|
# | grey|
# +-----+
#
# +-----+-----+
# | hair|  eye|
# +-----+-----+
# |black| blue|
# | grey|black|
# +-----+-----+

# %%
data=[(100,2,1),(200,3,4),(300,4,4)]
df=spark.createDataFrame(data).toDF("col1","col2","col3")
df.show()

#Arthmetic operations
df.select(df.col1 + df.col2).show()
df.select(df.col1 - df.col2).show() 
df.select(df.col1 * df.col2).show()
df.select(df.col1 / df.col2).show()
df.select(df.col1 % df.col2).show()

df.select(df.col2 > df.col3).show()
df.select(df.col2 < df.col3).show()
df.select(df.col2 == df.col3).show()
# Out:
# +----+----+----+
# |col1|col2|col3|
# +----+----+----+
# | 100|   2|   1|
# | 200|   3|   4|
# | 300|   4|   4|
# +----+----+----+
#
# +-------------+
# |(col1 + col2)|
# +-------------+
# |          102|
# |          203|
# |          304|
# +-------------+
#
# +-------------+
# |(col1 - col2)|
# +-------------+
# |           98|
# |          197|
# |          296|
# +-------------+
#
# +-------------+
# |(col1 * col2)|
# +-------------+
# |          200|
# |          600|
# |         1200|
# +-------------+
#
# +-----------------+
# |    (col1 / col2)|
# +-----------------+
# |             50.0|
# |66.66666666666667|
# |             75.0|
# +-----------------+
#
# +-------------+
# |(col1 % col2)|
# +-------------+
# |            0|
# |            2|
# |            0|
# +-------------+
#
# +-------------+
# |(col2 > col3)|
# +-------------+
# |         true|
# |        false|
# |        false|
# +-------------+
#
# +-------------+
# |(col2 < col3)|
# +-------------+
# |        false|
# |         true|
# |        false|
# +-------------+
#
# +-------------+
# |(col2 = col3)|
# +-------------+
# |        false|
# |        false|
# |         true|
# +-------------+

# %%
data=[("James","Bond","100",None),
      ("Ann","Varsa","200",'F'),
      ("Tom Cruise","XXX","400",''),
      ("Tom Brand",None,"400",'M')] 
columns=["fname","lname","id","gender"]
df=spark.createDataFrame(data,columns)
df.show()
# Out:
# +----------+-----+---+------+
# |     fname|lname| id|gender|
# +----------+-----+---+------+
# |     James| Bond|100|  null|
# |       Ann|Varsa|200|     F|
# |Tom Cruise|  XXX|400|      |
# | Tom Brand| null|400|     M|
# +----------+-----+---+------+

# %%
#alias
from pyspark.sql.functions import expr
df.select(df.fname.alias("first_name"), \
          df.lname.alias("last_name")
   ).show()

#Another example
df.select(expr(" fname ||','|| lname").alias("fullName") \
   ).show()
# Out:
# +----------+---------+
# |first_name|last_name|
# +----------+---------+
# |     James|     Bond|
# |       Ann|    Varsa|
# |Tom Cruise|      XXX|
# | Tom Brand|     null|
# +----------+---------+
#
# +--------------+
# |      fullName|
# +--------------+
# |    James,Bond|
# |     Ann,Varsa|
# |Tom Cruise,XXX|
# |          null|
# +--------------+

# %%
#alias
from pyspark.sql.functions import expr
df.select(df.fname.alias("first_name"), \
          df.lname.alias("last_name")
   ).show()

#Another example
df.select(expr(" fname ||','|| lname").alias("fullName") \
   ).show()
# Out:
# +----------+---------+
# |first_name|last_name|
# +----------+---------+
# |     James|     Bond|
# |       Ann|    Varsa|
# |Tom Cruise|      XXX|
# | Tom Brand|     null|
# +----------+---------+
#
# +--------------+
# |      fullName|
# +--------------+
# |    James,Bond|
# |     Ann,Varsa|
# |Tom Cruise,XXX|
# |          null|
# +--------------+

# %%
#asc, desc to sort ascending and descending order repsectively.
df.sort(df.fname.asc()).show()
df.sort(df.fname.desc()).show()
# Out:
# +----------+-----+---+------+
# |     fname|lname| id|gender|
# +----------+-----+---+------+
# |       Ann|Varsa|200|     F|
# |     James| Bond|100|  null|
# | Tom Brand| null|400|     M|
# |Tom Cruise|  XXX|400|      |
# +----------+-----+---+------+
#
# +----------+-----+---+------+
# |     fname|lname| id|gender|
# +----------+-----+---+------+
# |Tom Cruise|  XXX|400|      |
# | Tom Brand| null|400|     M|
# |     James| Bond|100|  null|
# |       Ann|Varsa|200|     F|
# +----------+-----+---+------+

# %%
#cast
df.select(df.fname,df.id.cast("int")).printSchema()
# Out:
# root
#  |-- fname: string (nullable = true)
#  |-- id: integer (nullable = true)

# %%
#between
df.filter(df.id.between(100,300)).show()
# Out:
# +-----+-----+---+------+
# |fname|lname| id|gender|
# +-----+-----+---+------+
# |James| Bond|100|  null|
# |  Ann|Varsa|200|     F|
# +-----+-----+---+------+

# %%
#contains
df.filter(df.fname.contains("Cruise")).show()
# Out:
# +----------+-----+---+------+
# |     fname|lname| id|gender|
# +----------+-----+---+------+
# |Tom Cruise|  XXX|400|      |
# +----------+-----+---+------+

# %%
#startswith, endswith()
df.filter(df.fname.startswith("T")).show()
df.filter(df.fname.endswith("Cruise")).show()
# Out:
# +----------+-----+---+------+
# |     fname|lname| id|gender|
# +----------+-----+---+------+
# |Tom Cruise|  XXX|400|      |
# | Tom Brand| null|400|     M|
# +----------+-----+---+------+
#
# +----------+-----+---+------+
# |     fname|lname| id|gender|
# +----------+-----+---+------+
# |Tom Cruise|  XXX|400|      |
# +----------+-----+---+------+

# %%
#isNull & isNotNull
df.filter(df.lname.isNull()).show()
df.filter(df.lname.isNotNull()).show()
# Out:
# +---------+-----+---+------+
# |    fname|lname| id|gender|
# +---------+-----+---+------+
# |Tom Brand| null|400|     M|
# +---------+-----+---+------+
#
# +----------+-----+---+------+
# |     fname|lname| id|gender|
# +----------+-----+---+------+
# |     James| Bond|100|  null|
# |       Ann|Varsa|200|     F|
# |Tom Cruise|  XXX|400|      |
# +----------+-----+---+------+

# %%
#like , rlike
df.select(df.fname,df.lname,df.id) \
  .filter(df.fname.like("%om%")).show()
# Out:
# +----------+-----+---+
# |     fname|lname| id|
# +----------+-----+---+
# |Tom Cruise|  XXX|400|
# | Tom Brand| null|400|
# +----------+-----+---+

# %%
df.select(df.fname.substr(1,2).alias("substr")).show()
# Out:
# +------+
# |substr|
# +------+
# |    Ja|
# |    An|
# |    To|
# |    To|
# +------+

# %%
#when & otherwise
from pyspark.sql.functions import when
df.select(df.fname,df.lname,when(df.gender=="M","Male") \
              .when(df.gender=="F","Female") \
              .when(df.gender==None ,"") \
              .otherwise(df.gender).alias("new_gender") \
    ).show()
# Out:
# +----------+-----+----------+
# |     fname|lname|new_gender|
# +----------+-----+----------+
# |     James| Bond|      null|
# |       Ann|Varsa|    Female|
# |Tom Cruise|  XXX|          |
# | Tom Brand| null|      Male|
# +----------+-----+----------+

# %%
#isin
li=["100","200"]
df.select(df.fname,df.lname,df.id) \
  .filter(df.id.isin(li)) \
  .show()
# Out:
# +-----+-----+---+
# |fname|lname| id|
# +-----+-----+---+
# |James| Bond|100|
# |  Ann|Varsa|200|
# +-----+-----+---+

# %%
#Create DataFrame with struct, array & map
from pyspark.sql.types import StructType,StructField,StringType,ArrayType,MapType
data=[(("James","Bond"),["Java","C#"],{'hair':'black','eye':'brown'}),
      (("Ann","Varsa"),[".NET","Python"],{'hair':'brown','eye':'black'}),
      (("Tom Cruise",""),["Python","Scala"],{'hair':'red','eye':'grey'}),
      (("Tom Brand",None),["Perl","Ruby"],{'hair':'black','eye':'blue'})]

schema = StructType([
        StructField('name', StructType([
            StructField('fname', StringType(), True),
            StructField('lname', StringType(), True)])),
        StructField('languages', ArrayType(StringType()),True),
        StructField('properties', MapType(StringType(),StringType()),True)
     ])
df=spark.createDataFrame(data,schema)
df.printSchema()

#Display's to console
root
 |-- name: struct (nullable = true)
 |    |-- fname: string (nullable = true)
 |    |-- lname: string (nullable = true)
 |-- languages: array (nullable = true)
 |    |-- element: string (containsNull = true)
 |-- properties: map (nullable = true)
 |    |-- key: string
 |    |-- value: string (valueContainsNull = true)
# Out:
#   File "<command-1951371118152285>", line 20
#     |-- name: struct (nullable = true)
#     ^
# IndentationError: unexpected indent

# %%
#getField from MapType
df.select(df.properties.getField("hair")).show()

#getField from Struct
df.select(df.name.getField("fname")).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1951371118152286> in <module>
#       1 #getField from MapType
# ----> 2 df.select(df.properties.getField("hair")).show()
#       3
#       4 #getField from Struct
#       5 df.select(df.name.getField("fname")).show()
#
# /databricks/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1798         """
#    1799         if name not in self.columns:
# -> 1800             raise AttributeError(
#    1801                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1802         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'properties'

# %%
#getItem() used with ArrayType
df.select(df.languages.getItem(1)).show()

#getItem() used with MapType
df.select(df.properties.getItem("hair")).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1951371118152287> in <module>
#       1 #getItem() used with ArrayType
# ----> 2 df.select(df.languages.getItem(1)).show()
#       3
#       4 #getItem() used with MapType
#       5 df.select(df.properties.getItem("hair")).show()
#
# /databricks/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1798         """
#    1799         if name not in self.columns:
# -> 1800             raise AttributeError(
#    1801                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1802         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'languages'
